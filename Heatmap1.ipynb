# %% [markdown]
# <a href="https://colab.research.google.com/github/sahil09130/AutoComplete/blob/main/Heatmap1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sns 
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6e39978a-1630-4ea9-80d7-5720f6a181bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6e39978a-1630-4ea9-80d7-5720f6a181bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['Financial_litercy_spreadsheet - Sheet1.csv']))

# %%
df2
x = df2.drop(columns=["Name of the State"],axis=1)
x
# Out:
#     General Literacy(in Percentage)  Financial Literacy (in percentage)
# 0                                60                                  23
# 1                                55                                  10
# 2                                61                                  20
# 3                                50                                   8
# 4                                60                                   4
# 5                                80                                  50
# 6                                68                                  83
# 7                                65                                  21
# 8                                73                                  16
# 9                                56                                  15
# 10                               67                                  25
# 11                               84                                  36
# ...

# %%
sns.heatmap( x , vmin=0 , vmax = 80, cmap='PuOr', annot =True )
plt.gcf().set_size_inches(25, 25)

plt.show()
